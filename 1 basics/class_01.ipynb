# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
a = [1, 2, 3, 4]
print type(a)
# Out:
# <type 'list'>

# %%
arr = np.asarray([[1, 2, 3, 4], [2, 3, 4, 5]])
print arr
print type(arr)
print arr.shape
# Out:
# [[1 2 3 4]
#  [2 3 4 5]]
# <type 'numpy.ndarray'>
# (2, 4)

# %%
a = np.zeros((4, 4, 2))
a[:, :, 1] += 1.0
a[:, 0, 1] *= 2.0
a[:, 1, 1] *= 3.0
a[:, 2, 1] *= 4.0
# print a[:, :, 0]
# print a[:, :, 1]
# print a

# %%
a = np.asarray(range(1, 100))

plt.figure(0)
plt.plot(a, 'r')
plt.plot(a**2, 'g.')
plt.plot(a**1.5, 'b')

plt.show()

# %%
arr = np.random.random((10000, 2))
arr1 = np.random.random((100, 5))
print arr.shape

plt.figure(0)
#plt.scatter(arr[:, 0],  arr[:, 1], color='black')
#plt.scatter(arr1[:, 0:1], arr1[:, 2], color='green')
plt.scatter(1, 4, color='green')
#plt.scatter(arr1[:, ], arr1[:, 2], color='orange')

plt.show()
# Out:
# (10000, 2)
